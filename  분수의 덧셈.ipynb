# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
numer1 = 9
denom1 = 2
numer2 = 1
denom2 = 3

# %%
denom = math.lcm(denom1, denom2)
denom
# Out:
# 6

# %%
[(numer1* (denom // denom1)) + (numer2 * (denom // denom2)), denom]
# Out:
# [29, 6]

# %%
def solution(numer1, denom1, numer2, denom2):
    num = denom1 * numer2 + denom2 * numer1
    denum = denom1 * denom2
    gcd = math.gcd(denum, num)
    return [num//gcd, denum//gcd]
