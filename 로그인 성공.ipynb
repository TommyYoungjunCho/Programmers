# %% [markdown]
# ![image.png](attachment:image.png)

# %%
input1 = ["meosseugi", "1234"]
input2 = ["programmer01", "15789"]
input3 = ["rabbit04", "98761"]

# %%
db1 = [["rardss", "123"], ["yyoom", "1234"], ["meosseugi", "1234"]]
db2 = [["programmer02", "111111"], ["programmer00", "134"], ["programmer01", "1145"]]
db3 = [["jaja11", "98761"], ["krong0313", "29440"], ["rabbit00", "111333"]]

# %%
for i in range(len(db3)):
    if input3[0] == db3[i][0]:
        if input3[1] == db3[i][1]:
            print ("login")
        elif input3[1] != db3[i][1]:
            print ("wrong pw")
    else:
        if i == len(db3) - 1:
            print('fail')
        else:
            pass
# Out:
# fail

# %%
len(db3)
# Out:
# 3

# %%
def solution(id_pw, db):
    for i in range(len(db)):
        if id_pw[0] == db[i][0]:
            if id_pw[1] == db[i][1]:
                print ("login")
            elif id_pw[1] != db[i][1]:
                print ("wrong pw")
        else:
            if i == len(db) - 1:
                print('fail')
            else:
                pass

# %%
solution(input3, db3)
# Out:
# fail
